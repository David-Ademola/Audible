# %%
import os

import kagglehub

# %%
# Download latest version
output_dir = os.path.join(os.getcwd(), "data")
path = kagglehub.dataset_download(
    "adarshsingh0903/audio-deepfake-detection-dataset", output_dir=output_dir
)

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.09G/1.09G [00:07<00:00, 151MB/s]
# Extracting files...
# Path to dataset files: /teamspace/studios/this_studio/data
